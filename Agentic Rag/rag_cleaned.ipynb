# %%
from rag_helper import RAGBase
from ingest import load_faq_data ,build_index
import os

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI(    base_url="https://openrouter.ai/api/v1",
    # Automatically pulls the key from your .env file
    api_key=os.getenv("OPENROUTER_API_KEY") )

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes—you can still join the course. Just keep in mind that if you want to earn a certificate, you’ll need to submit your capstone project while the submission period is still open.'

# %%
assistant.rag("How do I get a certificate?")
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes—you can still join the course after it has started. Just sign up and begin the homework while the submission form is open. (If you want a certificate, you’ll need to submit your project before the submission deadline.)'
