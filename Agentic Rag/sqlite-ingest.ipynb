# %%
from ingest import load_faq_data

documents = load_faq_data()
print(f"Loaded {len(documents)} documents")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ingest import load_faq_data
#       3 documents = load_faq_data()
#       4 print(f"Loaded {len(documents)} documents")
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:990, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1086, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1186, in get_data(self, path)
#
# KeyboardInterrupt:
